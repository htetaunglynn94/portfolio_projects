# %% [markdown]
# # Movie Recommendation System

# %%
# import major libraries
import os
from gdown import download
import numpy as np
import pandas as pd
from urllib import request
import re  # python regular expression
import difflib # compare sequences for strings and list


import ipywidgets as widgets
from IPython.display import display

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Based on ratings

# %% [markdown]
# ### Download data

# %%
# Download movie data
mv_file = "https://raw.githubusercontent.com/htetaunglynn94/portfolio_projects/refs/heads/main/data/mv.csv"
root = os.getcwd()
# path = os.path.join(root, "movies.csv")
# request.urlretrieve(mv_file, path)

# # Download class file
# class_file = "https://drive.google.com/uc?export=download&id=1aeS4F5QWJhmGWFhqNGId2XUuboG5NFF_"
# root = os.getcwd()
# path = os.path.join(root, "Uinterface.py")
# download(class_file, path, quiet=False)

# File size is very large and cannot read due to google virus scanning method
# need '!pip install gdown'
rating = "https://drive.google.com/uc?export=download&id=12SjCQWIAmb1TxZ1OLt5Cp7gcXffs9bt1"
path = os.path.join(root, "ratings.csv")
download(rating, path, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=12SjCQWIAmb1TxZ1OLt5Cp7gcXffs9bt1
# From (redirected): https://drive.google.com/uc?export=download&id=12SjCQWIAmb1TxZ1OLt5Cp7gcXffs9bt1&confirm=t&uuid=084260f3-91a7-4203-9c14-6f7f37c75035
# To: /content/ratings.csv
# 100%|██████████| 678M/678M [00:08<00:00, 83.3MB/s]
# '/content/ratings.csv'

# %% [markdown]
# ### Defined functions

# %%
def clean_title(title):
    return re.sub("[^a-zA-Z0-9 ]","",title)

def find_similar_movies(movie_id):
    cols = ['movieId', 'score', 'title', 'genres']

    # Extract userId of only users who rated higher than 4
    similar_users = ratings.query("movieId == @movie_id and rating > 4")["userId"].unique()
    # Extract movieId from those similar users, keeping rating above 4
    similar_user_recs = ratings.query("userId in @similar_users and rating > 4")["movieId"]


    # Compute percentages of similar users who liked each movie
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    # Filter only movies that more than 10% of similar users liked (removed weak recommendation)
    similar_user_recs = similar_user_recs[similar_user_recs > .10]


    # Filter all users who liked recommended movieId, keeping rating above 4
    all_users = ratings.query("movieId in @similar_user_recs.index & rating > 4")
    # Compute percentage of all users who liked each candidate movie
    all_users_recs = all_users['movieId'].value_counts() / len(all_users['userId'].unique())

    # movieId for "Similar users like percentage" and "all users like percentage"
    rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]

    # Compute recommendation socre
    rec_percentages['score'] = rec_percentages['similar'] / rec_percentages['all']
    rec_percentages = rec_percentages.sort_values("score", ascending=False)

    # Return largest 20 rows merging with movie data
    return rec_percentages.nlargest(n=20, columns="score").merge(df, on='movieId')[cols]


def search(title, n_mov):
    title = clean_title(title) # clean the title
    query_vec =vectorizer.transform([title]) # transform title into number (coordinates & values)
    similarity = cosine_similarity(query_vec, tfidf).flatten() # 2-D to 1-D (shape: (62423,)) --> btw 0 and 1
    indices = np.argsort(similarity)[-n_mov:][::-1] # sort the similarity in reverse order
    results = df.iloc[indices] # start from the end and go backward one step at a time
    return results


# def user_interface(df, vectorizer, tfidf):
def user_interface():

    def search_operation():
        """
        Handle search operation when button is clicked or Enter is pressed
        """
        title = movie_input.value.strip()
        # print(title)

        # can use due to global variables
        with movie_list:  # setup and clean up operations automatically
            movie_list.clear_output()
            if len(title) > 2:
                try:
                    display(search(title, range_slider.value))
                except Exception as e:
                    print(f"Search error: {e}")
            else:
                print("Please enter at least 3 characters")

    # Text input widgets
    movie_input = widgets.Text(value = '',                          # empty initial value
                            placeholder = 'Type a movie title...',  # place holder message
                            description = 'Movie Title:',           # description
                            style = {'description_width': '100px'}, # description width
                            layout = widgets.Layout(width='300px')) # layout for text box

    # Label
    n_movies = widgets.Label("No. of recommended movies:")    # label before the range

    # Create search button
    search_button = widgets.Button(description='Search',      # search button
                                button_style='primary')


    # Slider widget
    range_slider = widgets.IntSlider(min=0, max=20, step=1, value=2)
    min_label = widgets.Label("min")
    max_label = widgets.Label("max")


    # Create horizontal layout
    # Put input text box and button at the same row
    search_box = widgets.HBox([movie_input, search_button])
    range = widgets.HBox([min_label, range_slider, max_label])

    # Output area for results
    movie_list = widgets.Output()  # declare as global variable

    # Connect ONLY button click and Enter key
    search_button.on_click(lambda c: search_operation())
    movie_input.on_submit(lambda s: search_operation())

    display(search_box, n_movies, range, movie_list)

# %% [markdown]
# ### Data loading

# %%
# Load movie file
df = pd.read_csv(mv_file)
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# `re.sub(pattern, replacement, string)`
#
# * `[^...]` means "NOT any of these characters"
# * `a-zA-Z` means all lowercase and uppercase letters
# * `0-9`**bold text** means all digits

# %%
df['clean_title'] = df['title'].apply(clean_title)
df.sample(5)
# Out:
#        movieId                                              title  \
# 50989   182185                              Elmer Elephant (1936)
# 61739   206775                           Girl From Nowhere (2017)
# 24594   121857  Too Tough to Die: A Tribute to Johnny Ramone (...
# 54655   190081                                       Lucia (1968)
# 15632    82283                             Secret Ceremony (1968)
#
#                genres                                       clean_title
# 50989       Animation                               Elmer Elephant 1936
# 61739        Thriller                            Girl From Nowhere 2017
# 24594     Documentary  Too Tough to Die A Tribute to Johnny Ramone 2006
# 54655           Drama                                        Lucia 1968
# 15632  Drama|Thriller                              Secret Ceremony 1968

# %% [markdown]
# `TfidfVectorizer` converts a collection of text documents into a matrix of `TF-IDF` features, where:
#
# - `TF` (Term Frequency) → How often a word appears in a document
# - `IDF` (Inverse Document Frequency) → How unique that word is across all documents
#
# It’s basically a way to transform text into numerical vectors while down-weighting common words like “the” and “is”.

# %%
# Consider for unigrams and bigrams
vectorizer = TfidfVectorizer(ngram_range=(1,2)) #(unigram, bigram)
tfidf = vectorizer.fit_transform(df['clean_title']) # output is sparse matrix
tfidf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 446566 stored elements and shape (62423, 170073)>

# %%
ratings = pd.read_csv("ratings.csv")
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
user_interface()
# Out:
#        movieId               title  \
# 14813    78499  Toy Story 3 (2010)
# 3021      3114  Toy Story 2 (1999)
#
#                                                  genres
# 14813  Adventure|Animation|Children|Comedy|Fantasy|IMAX
# 3021        Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# ## Based on

# %%
url = "https://raw.githubusercontent.com/htetaunglynn94/portfolio_projects/refs/heads/main/data/movies.csv"
mvd = pd.read_csv(url)
mvd.sample(5)
# Out:
#       index    budget                                     genres  \
# 1001   1001  50000000  Action Adventure Science Fiction Thriller
# 2215   2215  20000000                                      Drama
# 1672   1672  30000000         Adventure Drama Action History War
# 2575   2575  15000000                            Horror Thriller
# 3999   3999   2159280                                      Drama
#
#                        homepage      id  \
# 1001                        NaN   15268
# 2215     http://burntmovie.com/  295964
# 1672  http://www.1911movie.com/   76349
# 2575                        NaN    9793
# 3999                        NaN  209274
#
#                                                keywords original_language  \
# 1001  martial arts revenge street fighter based on v...                en
# 2215         london england cook restaurant diva career                en
# 1672       martial arts sword revolution blood gunfight                zh
# 2575                 new mexico mutant assault survival                en
# 3999                         nun mine jew jewish poland                pl
#
#                              original_title  \
# 1001  Street Fighter: The Legend of Chun-Li
# 2215                                  Burnt
# 1672                                   辛亥革命
# 2575                 The Hills Have Eyes II
# 3999                                    Ida
#
#                                                overview  popularity  ...  \
# 1001  When a teenager, Chun-Li witnesses the kidnapp...    8.139676  ...
# 2215  Adam Jones is a Chef who destroyed his career ...   30.477114  ...
# 1672  At the beginning of the 20th century, China is...    4.065212  ...
# 2575  A group of National Guard trainees find themse...   17.141376  ...
# 3999  Poland, 1962. Anna is a novice, an orphan brou...   13.265432  ...
#
#      runtime                                   spoken_languages    status  \
# 1001    97.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2215   100.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 1672   125.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 2575    89.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3999    80.0            [{"iso_639_1": "pl", "name": "Polski"}]  Released
#
#                                                 tagline  \
# 1001           Some fight for power. Some fight for us.
# 2215  Never underestimate a man with everything to l...
# 1672                            Fall of the Last Empire
# 2575                                 Help isn't coming.
# 3999                                                NaN
#
#                                       title vote_average vote_count  \
# 1001  Street Fighter: The Legend of Chun-Li          3.9        112
# 2215                                  Burnt          6.3        950
# 1672                                   1911          5.0         41
# 2575                  The Hills Have Eyes 2          5.2        351
# 3999                                    Ida          7.1        260
#
#                                                    cast  \
# 1001  Kristin Kreuk Chris Klein Neal McDonough Micha...
# 2215  Bradley Cooper Sienna Miller Lily James Alicia...
# 1672  Jackie Chan Li Bingbing Joan Chen Jaycee Chan ...
# 2575  Michael Bailey Smith Archie Kao Jay Acovone Je...
# 3999  Agata Trzebuchowska Agata Kulesza Joanna Kulig...
#
#                                                    crew  \
# 1001  [{'name': 'Andrzej Bartkowiak', 'gender': 2, '...
# 2215  [{'name': 'Bob Weinstein', 'gender': 2, 'depar...
# 1672  [{'name': 'Jackie Chan', 'gender': 2, 'departm...
# 2575  [{'name': 'Wes Craven', 'gender': 2, 'departme...
# 3999  [{'name': 'Kristian Eidnes Andersen', 'gender'...
#
#                     director
# 1001      Andrzej Bartkowiak
# 2215              John Wells
# 1672             Jackie Chan
# 2575            Martin Weisz
# 3999  Pawe\u0142 Pawlikowski
#
# [5 rows x 24 columns]

# %%
mvd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
#  15  spoken_languages      4803 non-null   object
#  16  status                4803 non-null   object
#  17  tagline               3959 non-null   object
#  18  title                 4803 non-null   object
#  19  vote_average          4803 non-null   float64
#  20  vote_count            4803 non-null   int64
#  21  cast                  4760 non-null   object
#  22  crew                  4803 non-null   object
#  23  director              4773 non-null   object
# dtypes: float64(3), int64(5), object(16)
# memory usage: 900.7+ KB

# %%
mvd.shape
# Out:
# (4803, 24)

# %%
def similar_movies(features, vectorizer, ):
    mvd[features] = mvd[features].fillna('') # imputation
    combined_features = mvd[selected_features].agg('__'.join, axis=1) # feature combination
    feature_vectors = vectorizer.fit_transform(combined_features)
    similarity = cosine_similarity(feature_vectors) # apply similarity
    movie_titles = mvd['title'].unique() # get all movie titles (total=4800)


vectorizer = TfidfVectorizer()

# %%
selected_features = ['genres','keywords','tagline','cast','director', 'overview']

# %%
mvd[selected_features].isna().sum()
# Out:
# genres       28
# keywords    412
# tagline     844
# cast         43
# director     30
# overview      3
# dtype: int64

# %%
na_idx = mvd[mvd.isna().any(axis=1)].index
na_idx
# Out:
# Index([  10,   15,   24,   27,   33,   34,   47,   49,   56,   58,
#        ...
#        4792, 4793, 4794, 4795, 4797, 4798, 4799, 4800, 4801, 4802],
#       dtype='int64', length=3371)

# %%
mvd.loc[na_idx]
# Out:
#       index     budget                                     genres  \
# 10       10  270000000   Adventure Fantasy Action Science Fiction
# 15       15  225000000                   Adventure Family Fantasy
# 24       24  207000000                     Adventure Drama Action
# 27       27  209000000  Thriller Action Adventure Science Fiction
# 33       33  210000000  Adventure Action Science Fiction Thriller
# ...     ...        ...                                        ...
# 4798   4798     220000                      Action Crime Thriller
# 4799   4799       9000                             Comedy Romance
# 4800   4800          0              Comedy Drama Romance TV Movie
# 4801   4801          0                                        NaN
# 4802   4802          0                                Documentary
#
#                                                homepage      id  \
# 10                              http://www.superman.com    1452
# 15                                                  NaN    2454
# 24                                                  NaN     254
# 27                                                  NaN   44833
# 33                                                  NaN   36668
# ...                                                 ...     ...
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 10    saving the world dc comics invulnerability seq...                en
# 15    based on novel fictional place brother sister ...                en
# 24    film business screenplay show business film ma...                en
# 27        fight u.s. navy mind reading hong kong soccer                en
# 33    mutant marvel comic based on comic book superh...                en
# ...                                                 ...               ...
# 4798  united states\u2013mexico barrier legs arms pa...                es
# 4799                                                NaN                en
# 4800  date love at first sight narration investigati...                en
# 4801                                                NaN                en
# 4802               obsession camcorder crush dream girl                en
#
#                                 original_title  \
# 10                            Superman Returns
# 15    The Chronicles of Narnia: Prince Caspian
# 24                                   King Kong
# 27                                  Battleship
# 33                       X-Men: The Last Stand
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  popularity  ...  \
# 10    Superman returns to discover his 5-year absenc...   57.925623  ...
# 15    One year after their incredible adventures in ...   53.978602  ...
# 24    In 1933 New York, an overly ambitious movie pr...   61.226010  ...
# 27    When mankind beams a radio signal into space, ...   64.928382  ...
# 33    When a cure is found to treat mutations, lines...    3.857526  ...
# ...                                                 ...         ...  ...
# 4798  El Mariachi just wants to play his guitar and ...   14.269792  ...
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552  ...
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476  ...
# 4801  When ambitious New York attorney Sam is sent t...    0.857008  ...
# 4802  Ever since the second grade when he first saw ...    1.929883  ...
#
#      runtime                                   spoken_languages    status  \
# 10     154.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 15     150.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 24     187.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 27     131.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 33     104.0           [{"iso_639_1": "en", "name": "English"}]  Released
# ...      ...                                                ...       ...
# 4798    81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4799    85.0                                                 []  Released
# 4800   120.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4801    98.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4802    90.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 10                                                  NaN
# 15                                 Hope has a new face.
# 24                      The eighth wonder of the world.
# 27                   The Battle for Earth Begins at Sea
# 33                                         Take a Stand
# ...                                                 ...
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800                                                NaN
# 4801                           A New Yorker in Shanghai
# 4802                                                NaN
#
#                                          title vote_average vote_count  \
# 10                            Superman Returns          5.4       1400
# 15    The Chronicles of Narnia: Prince Caspian          6.3       1630
# 24                                   King Kong          6.6       2337
# 27                                  Battleship          5.5       2114
# 33                       X-Men: The Last Stand          6.3       3525
# ...                                        ...          ...        ...
# 4798                               El Mariachi          6.6        238
# 4799                                 Newlyweds          5.9          5
# 4800                 Signed, Sealed, Delivered          7.0          6
# 4801                          Shanghai Calling          5.7          7
# 4802                         My Date with Drew          6.3         16
#
#                                                    cast  \
# 10    Brandon Routh Kevin Spacey Kate Bosworth James...
# 15    Ben Barnes William Moseley Anna Popplewell Ska...
# 24    Naomi Watts Jack Black Adrien Brody Thomas Kre...
# 27    Taylor Kitsch Alexander Skarsg\u00e5rd Rihanna...
# 33    Hugh Jackman Halle Berry Ian McKellen Patrick ...
# ...                                                 ...
# 4798  Carlos Gallardo Jaime de Hoyos Peter Marquardt...
# 4799  Edward Burns Kerry Bish\u00e9 Marsha Dietlein ...
# 4800  Eric Mabius Kristin Booth Crystal Lowe Geoff G...
# 4801  Daniel Henney Eliza Coupe Bill Paxton Alan Ruc...
# 4802  Drew Barrymore Brian Herzlinger Corey Feldman ...
#
#                                                    crew          director
# 10    [{'name': 'Roger Mussenden', 'gender': 2, 'dep...      Bryan Singer
# 15    [{'name': 'Liz Mullane', 'gender': 1, 'departm...    Andrew Adamson
# 24    [{'name': 'James Newton Howard', 'gender': 2, ...     Peter Jackson
# 27    [{'name': 'Paul Rubell', 'gender': 2, 'departm...        Peter Berg
# 33    [{'name': 'Mark Goldblatt', 'gender': 2, 'depa...      Brett Ratner
# ...                                                 ...               ...
# 4798  [{'name': 'Robert Rodriguez', 'gender': 0, 'de...  Robert Rodriguez
# 4799  [{'name': 'Edward Burns', 'gender': 2, 'depart...      Edward Burns
# 4800  [{'name': 'Carla Hetland', 'gender': 0, 'depar...       Scott Smith
# 4801  [{'name': 'Daniel Hsia', 'gender': 2, 'departm...       Daniel Hsia
# 4802  [{'name': 'Clark Peterson', 'gender': 2, 'depa...  Brian Herzlinger
#
# [3371 rows x 24 columns]

# %%
mvd[selected_features] = mvd[selected_features].fillna('')
mvd[selected_features].isna().sum()
# Out:
# genres      0
# keywords    0
# tagline     0
# cast        0
# director    0
# overview    0
# dtype: int64

# %%
# Imputation
for feature in selected_features:
    mvd[feature] = mvd[feature].fillna('')
mvd.iloc[na_idx].head()
# Out:
#     index     budget                                     genres  \
# 10     10  270000000   Adventure Fantasy Action Science Fiction
# 15     15  225000000                   Adventure Family Fantasy
# 24     24  207000000                     Adventure Drama Action
# 27     27  209000000  Thriller Action Adventure Science Fiction
# 33     33  210000000  Adventure Action Science Fiction Thriller
#
#                    homepage     id  \
# 10  http://www.superman.com   1452
# 15                      NaN   2454
# 24                      NaN    254
# 27                      NaN  44833
# 33                      NaN  36668
#
#                                              keywords original_language  \
# 10  saving the world dc comics invulnerability seq...                en
# 15  based on novel fictional place brother sister ...                en
# 24  film business screenplay show business film ma...                en
# 27      fight u.s. navy mind reading hong kong soccer                en
# 33  mutant marvel comic based on comic book superh...                en
#
#                               original_title  \
# 10                          Superman Returns
# 15  The Chronicles of Narnia: Prince Caspian
# 24                                 King Kong
# 27                                Battleship
# 33                     X-Men: The Last Stand
#
#                                              overview  popularity  ...  \
# 10  Superman returns to discover his 5-year absenc...   57.925623  ...
# 15  One year after their incredible adventures in ...   53.978602  ...
# 24  In 1933 New York, an overly ambitious movie pr...   61.226010  ...
# 27  When mankind beams a radio signal into space, ...   64.928382  ...
# 33  When a cure is found to treat mutations, lines...    3.857526  ...
#
#    runtime                                   spoken_languages    status  \
# 10   154.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 15   150.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 24   187.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 27   131.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 33   104.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                tagline  \
# 10
# 15                Hope has a new face.
# 24     The eighth wonder of the world.
# 27  The Battle for Earth Begins at Sea
# 33                        Take a Stand
#
#                                        title vote_average vote_count  \
# 10                          Superman Returns          5.4       1400
# 15  The Chronicles of Narnia: Prince Caspian          6.3       1630
# 24                                 King Kong          6.6       2337
# 27                                Battleship          5.5       2114
# 33                     X-Men: The Last Stand          6.3       3525
#
#                                                  cast  \
# 10  Brandon Routh Kevin Spacey Kate Bosworth James...
# 15  Ben Barnes William Moseley Anna Popplewell Ska...
# 24  Naomi Watts Jack Black Adrien Brody Thomas Kre...
# 27  Taylor Kitsch Alexander Skarsg\u00e5rd Rihanna...
# 33  Hugh Jackman Halle Berry Ian McKellen Patrick ...
#
#                                                  crew        director
# 10  [{'name': 'Roger Mussenden', 'gender': 2, 'dep...    Bryan Singer
# 15  [{'name': 'Liz Mullane', 'gender': 1, 'departm...  Andrew Adamson
# 24  [{'name': 'James Newton Howard', 'gender': 2, ...   Peter Jackson
# 27  [{'name': 'Paul Rubell', 'gender': 2, 'departm...      Peter Berg
# 33  [{'name': 'Mark Goldblatt', 'gender': 2, 'depa...    Brett Ratner
#
# [5 rows x 24 columns]

# %%
mvd[selected_features].isna().sum()
# Out:
# genres      0
# keywords    0
# tagline     0
# cast        0
# director    0
# overview    0
# dtype: int64

# %%
mvd.query("genres == ''").shape[0]
# Out:
# 28

# %%
# main procedure
combined_features = mvd[selected_features].agg('__'.join, axis=1)
combined_features
# Out:
# 0       Action Adventure Fantasy Science Fiction__cult...
# 1       Adventure Fantasy Action__ocean drug abuse exo...
# 2       Action Adventure Crime__spy based on novel sec...
# 3       Action Crime Drama Thriller__dc comics crime f...
# 4       Action Adventure Science Fiction__based on nov...
#                               ...
# 4798    Action Crime Thriller__united states\u2013mexi...
# 4799    Comedy Romance____A newlywed couple's honeymoo...
# 4800    Comedy Drama Romance TV Movie__date love at fi...
# 4801    ____A New Yorker in Shanghai__Daniel Henney El...
# 4802    Documentary__obsession camcorder crush dream g...
# Length: 4803, dtype: object

# %%
combined_features[10]
# Out:
# 'Adventure Fantasy Action Science Fiction__saving the world dc comics invulnerability sequel superhero____Brandon Routh Kevin Spacey Kate Bosworth James Marsden Parker Posey__Bryan Singer__Superman returns to discover his 5-year absence has allowed Lex Luthor to walk free, and that those he was closest too felt abandoned and have moved on. Luthor plots his ultimate revenge that could see millions killed and change the face of the planet forever, as well as ridding himself of the Man of Steel.'

# %%
mvd.loc[10, selected_features]
# Out:
# genres               Adventure Fantasy Action Science Fiction
# keywords    saving the world dc comics invulnerability seq...
# tagline
# cast        Brandon Routh Kevin Spacey Kate Bosworth James...
# director                                         Bryan Singer
# overview    Superman returns to discover his 5-year absenc...
# Name: 10, dtype: object

# %%
vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combined_features)
print(feature_vectors[4])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 66 stored elements and shape (1, 45460)>
#   Coords	Values
#   (0, 1462)	0.04837561565607358
#   (0, 1743)	0.05593312100515051
#   (0, 35993)	0.06203846480278026
#   (0, 37946)	0.09636393172081796
#   (0, 43581)	0.0699217792894617
#   (0, 40204)	0.06591025110954918
#   (0, 44806)	0.11413289949467749
#   (0, 29629)	0.07451325915017669
#   (0, 21880)	0.03250772839584474
#   (0, 40992)	0.02419750879373696
#   (0, 29779)	0.07729913248365236
#   (0, 4522)	0.07641842636038708
#   (0, 2604)	0.09960750642262593
#   (0, 2567)	0.04291332114170886
#   (0, 14681)	0.1230283828047165
#   (0, 21941)	0.05135074917737557
#   (0, 29378)	0.07940420756451147
#   (0, 28468)	0.08378422293944751
#   (0, 44258)	0.04413527145881766
#   (0, 15756)	0.14448532312731607
#   (0, 26186)	0.2700057897045326
#   (0, 26845)	0.15010402694498695
#   (0, 41393)	0.09765215341040448
#   (0, 32143)	0.17156096726758654
#   (0, 21250)	0.11758280008083831
#   :	:
#   (0, 43882)	0.14448532312731607
#   (0, 16645)	0.08433754461285144
#   (0, 27293)	0.10356904544403314
#   (0, 6903)	0.1064798517047819
#   (0, 21387)	0.14448532312731607
#   (0, 41362)	0.1350028948522663
#   (0, 31453)	0.09832959526635213
#   (0, 4241)	0.3431219345351731
#   (0, 33568)	0.11867017753675378
#   (0, 13946)	0.14012711785935336
#   (0, 14251)	0.10212164643681919
#   (0, 9189)	0.12223109052125543
#   (0, 6068)	0.12976344467458528
#   (0, 8442)	0.1350028948522663
#   (0, 33291)	0.1536649399294886
#   (0, 19934)	0.07057608573011544
#   (0, 20733)	0.1116389825831188
#   (0, 44177)	0.048464838966862114
#   (0, 19350)	0.043184400424158366
#   (0, 33123)	0.10683177021257698
#   (0, 39339)	0.10613416217129097
#   (0, 21954)	0.08161762431084978
#   (0, 30906)	0.07672006863042853
#   (0, 33852)	0.1536649399294886
#   (0, 18952)	0.10387185691691042

# %%
# Apply consine_similarity
similarity = cosine_similarity(feature_vectors)
similarity
# Out:
# array([[1.        , 0.0455758 , 0.02085448, ..., 0.02498382, 0.01138446,
#         0.00663412],
#        [0.0455758 , 1.        , 0.03905452, ..., 0.04548676, 0.03122382,
#         0.01623675],
#        [0.02085448, 0.03905452, 1.        , ..., 0.02536949, 0.01180806,
#         0.01466201],
#        ...,
#        [0.02498382, 0.04548676, 0.02536949, ..., 1.        , 0.03796027,
#         0.02027747],
#        [0.01138446, 0.03122382, 0.01180806, ..., 0.03796027, 1.        ,
#         0.03352437],
#        [0.00663412, 0.01623675, 0.01466201, ..., 0.02027747, 0.03352437,
#         1.        ]])

# %%
similarity.shape
# Out:
# (4803, 4803)

# %%
duplicated_titles = mvd[mvd['title'].duplicated()]['title'].values
duplicated_titles
# Out:
# array(['The Host', 'Out of the Blue', 'Batman'], dtype=object)

# %%
for t in duplicated_titles:
    display(mvd[mvd['title'] == t]['title'])
# Out:
# 972     The Host
# 2877    The Host
# Name: title, dtype: object
# 3647    Out of the Blue
# 3693    Out of the Blue
# Name: title, dtype: object
# 1359    Batman
# 4267    Batman
# Name: title, dtype: object

# %%
# [The Host', 'Out of the Blue', 'Batman'] are duplicated
movie_titles = mvd['title'].unique()
print(movie_titles)
# Out:
# ['Avatar' "Pirates of the Caribbean: At World's End" 'Spectre' ...
#  'Signed, Sealed, Delivered' 'Shanghai Calling' 'My Date with Drew']

# %%
len(movie_titles)
# Out:
# 4800

# %%
# Movie input
mv_name = 'superman'
matched_movies = difflib.get_close_matches(mv_name, movie_titles)[0]
matched_movies
# Out:
# 'Superman'

# %%
mv_idx = mvd[mvd['title'] == matched_movies]['index'].values[0]
mv_idx
# Out:
# np.int64(813)

# %%
similarity_score = list(enumerate(similarity[mv_idx]))
print(similarity_score)
# Out:
# [(0, np.float64(0.03572841888271902)), (1, np.float64(0.0476983065845937)), (2, np.float64(0.02694894709290134)), (3, np.float64(0.05038152731818984)), (4, np.float64(0.05506037555304375)), (5, np.float64(0.0691670400814669)), (6, np.float64(0.023568948473306137)), (7, np.float64(0.06503281965570977)), (8, np.float64(0.025864887312138374)), (9, np.float64(0.07768142630850203)), (10, np.float64(0.1988831746461673)), (11, np.float64(0.02796442414786626)), (12, np.float64(0.03583144839022207)), (13, np.float64(0.024300139943190545)), (14, np.float64(0.17385083659421555)), (15, np.float64(0.021840107250937584)), (16, np.float64(0.044500403163833996)), (17, np.float64(0.03774546616981283)), (18, np.float64(0.052730997919447936)), (19, np.float64(0.02841262534094178)), (20, np.float64(0.06656278963983432)), (21, np.float64(0.02352698399720219)), (22, np.float64(0.013381478650801788)), (23, np.float64(0.016993018788790174)), (24, np.float64(0.025410219100269638)), (25, np.float64(0.020456646751398008)), (26, np.float64(0.03453785726790934)), (27, np.float64(0.05292203345040132)), (28, np.float64(0.022878682014107844)), (29, np.float64(0.03097940855628198)), (30, np.float64(0.08723209454440256)), (31, np.float64(0.03026005409855676)), (32, np.float64(0.03739709391677407)), (33, np.float64(0.018261546026756392)), (34, np.float64(0.017738817177787435)), (35, np.float64(0.02484552477949808)), (36, np.float64(0.03495234264502946)), (37, np.float64(0.02090380377757818)), (38, np.float64(0.02331456093025088)), (39, np.float64(0.032821849947315226)), (40, np.float64(0.03576416653745704)), (41, np.float64(0.05549971491141387)), (42, np.float64(0.06891745318717835)), (43, np.float64(0.041058393009183035)), (44, np.float64(0.007874835443387334)), (45, np.float64(0.08632618969962146)), (46, np.float64(0.06787973901818192)), (47, np.float64(0.04886849945513258)), (48, np.float64(0.04409673629964228)), (49, np.float64(0.015480835663632633)), (50, np.float64(0.03800846850175997)), (51, np.float64(0.02758143204000316)), (52, np.float64(0.03176763502225174)), (53, np.float64(0.03356102326447641)), (54, np.float64(0.018504113872314133)), (55, np.float64(0.017618388824290416)), (56, np.float64(0.02482848219120616)), (57, np.float64(0.02073830925792186)), (58, np.float64(0.02441394181998415)), (59, np.float64(0.05158373572012313)), (60, np.float64(0.026619800108989778)), (61, np.float64(0.02006793395980498)), (62, np.float64(0.0498047181942107)), (63, np.float64(0.0229990006272323)), (64, np.float64(0.07687238145908368)), (65, np.float64(0.06765209126675445)), (66, np.float64(0.013197530644077193)), (67, np.float64(0.015624003755599318)), (68, np.float64(0.009949652090754695)), (69, np.float64(0.049784613299283284)), (70, np.float64(0.025581668678281464)), (71, np.float64(0.034719555164793525)), (72, np.float64(0.10848394537091569)), (73, np.float64(0.030786388517534072)), (74, np.float64(0.03197483377625562)), (75, np.float64(0.037690587062166554)), (76, np.float64(0.06114445186365687)), (77, np.float64(0.017674964500770895)), (78, np.float64(0.018777998969818535)), (79, np.float64(0.09101540973008126)), (80, np.float64(0.03342653927944911)), (81, np.float64(0.04104150965439329)), (82, np.float64(0.025910913438016613)), (83, np.float64(0.033752941265023005)), (84, np.float64(0.028927269899069265)), (85, np.float64(0.055150997033615035)), (86, np.float64(0.0314646265264662)), (87, np.float64(0.02403066628489853)), (88, np.float64(0.01452989696152696)), (89, np.float64(0.013810998167082334)), (90, np.float64(0.039042379506420935)), (91, np.float64(0.04882575818373775)), (92, np.float64(0.031598822989212086)), (93, np.float64(0.04603348504755654)), (94, np.float64(0.012819291397780336)), (95, np.float64(0.050563157506838444)), (96, np.float64(0.03233855592707611)), (97, np.float64(0.03157784302429184)), (98, np.float64(0.024918081720688868)), (99, np.float64(0.020905477694041063)), (100, np.float64(0.022923257446935293)), (101, np.float64(0.03509962191608 ...

# %%
len(similarity_score)
# Out:
# 4803

# %%
sorted_similar_movies = sorted(similarity_score, key=lambda x: x[1], reverse=True)
sorted_similar_movies[:5]
# Out:
# [(813, np.float64(0.9999999999999998)),
#  (2433, np.float64(0.35925472712577666)),
#  (870, np.float64(0.3243009266298027)),
#  (10, np.float64(0.1988831746461673)),
#  (1296, np.float64(0.19201803929728556))]

# %%
indices = [m[0] for m in sorted_similar_movies[:20]]
indices
# Out:
# [813,
#  2433,
#  870,
#  10,
#  1296,
#  14,
#  72,
#  473,
#  3583,
#  79,
#  1801,
#  4659,
#  30,
#  196,
#  45,
#  119,
#  1890,
#  2015,
#  1314,
#  1740]

# %%
for _, title in enumerate(indices):
    get_movie_names = mvd[mvd.index == title]['title'].values[0]
    print(f"{_+1}. {get_movie_names}")
# Out:
# 1. Superman
# 2. Superman IV: The Quest for Peace
# 3. Superman II
# 4. Superman Returns
# 5. Superman III
# 6. Man of Steel
# 7. Suicide Squad
# 8. Mars Attacks!
# 9. Our Idiot Brother
# 10. Iron Man 2
# 11. Welcome to Mooseport
# 12. Horse Camp
# 13. Spider-Man 2
# 14. Megamind
# 15. World War Z
# 16. Batman Begins
# 17. Don Juan DeMarco
# 18. Spaceballs
# 19. Extreme Measures
# 20. Kick-Ass 2
